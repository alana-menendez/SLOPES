# %%
import xarray
import numpy as np

# %%
! pwd
# Out:
# /home/jovyan/shared-public/SLOPES

# %%
pigments_400_600nm = xarray.open_dataset('../SLOPES/results_cdom_slopes/pigments_400_600nm.nc')
pigments_400_450nm = xarray.open_dataset('../SLOPES/results_cdom_slopes/pigments_400_450nm.nc')
pigments_350_600nm = xarray.open_dataset('../SLOPES/results_cdom_slopes/pigments_350_600nm.nc')
pigments_350_450nm = xarray.open_dataset('../SLOPES/results_cdom_slopes/pigments_350_450nm.nc')
pigments_350_450nm_oo = xarray.open_dataset('../SLOPES/results_cdom_slopes/pigments_350_450nm_oo.nc')
pigments_350_600nm_oo_ber = xarray.open_dataset('../SLOPES/results_cdom_slopes/pigments_350_600nm_oo_ber.nc')
pigments_350_450nm_oo_ber = xarray.open_dataset('../SLOPES/results_cdom_slopes/pigments_350_450nm_oo_ber.nc')
pigments_400_600nm_oo_ber = xarray.open_dataset('../SLOPES/results_cdom_slopes/pigments_400_600nm_oo_ber.nc')
pigments_400_450nm_oo_ber = xarray.open_dataset('../SLOPES/results_cdom_slopes/pigments_400_450nm_oo_ber.nc')

# %%
! pwd
# Out:
# /home/jovyan/shared-public/SLOPES

# %%
import sys
import os

# Path to the directory containing utils.py
utils_dir = os.path.abspath('../SLOPES/pace-rrs-inversions-pigments')

# Add the directory to the system path
sys.path.append(utils_dir)

# Import the utils module
import utils

# %%
scdom_400_600 = pigments_400_600nm['scdom']
scdom_400_450 = pigments_400_450nm['scdom']
scdom_350_600 = pigments_350_600nm['scdom']
scdom_350_450 = pigments_350_450nm['scdom']
scdom_350_450_oo = pigments_350_450nm_oo['scdom']
scdom_350_600_oo_ber = pigments_350_600nm_oo_ber['scdom']
scdom_350_450_oo_ber = pigments_350_450nm_oo_ber['scdom']
scdom_400_600_oo_ber = pigments_400_600nm_oo_ber['scdom']
scdom_400_450_oo_ber = pigments_400_450nm_oo_ber['scdom']
#utils.plot_pigments(pigments_400_600nm['scdom'], 0.019, 0.020, 'scdom')

# %%
acdom_400_from_400_600 = pigments_400_600nm['acdom_400']
acdom_400_from_400_450 = pigments_400_450nm['acdom_400']
acdom_400_from_350_600 = pigments_350_600nm['acdom_400']
acdom_400_from_350_450 = pigments_350_450nm['acdom_400']
acdom_400_from_350_450_oo = pigments_350_450nm_oo['acdom_400']
acdom_400_from_350_600_oo_ber = pigments_350_600nm_oo_ber['acdom_400']
acdom_400_from_350_450_oo_ber = pigments_350_450nm_oo_ber['acdom_400']
acdom_400_from_400_600_oo_ber = pigments_400_600nm_oo_ber['acdom_400']
acdom_400_from_400_450_oo_ber = pigments_400_450nm_oo_ber['acdom_400']
#utils.plot_pigments(pigments_400_600nm['acdom_400'], 0.05, 0.20, 'acdom_400')

# %%
import matplotlib.pyplot as plt

# %%
scdom_400_600=np.array(scdom_400_600)
scdom_400_450=np.array(scdom_400_450)
scdom_350_600=np.array(scdom_350_600)
scdom_350_450=np.array(scdom_350_450)
scdom_350_450_oo=np.array(scdom_350_450_oo)
scdom_350_600_oo_ber=np.array(scdom_350_600_oo_ber)
scdom_350_450_oo_ber=np.array(scdom_350_450_oo_ber)
scdom_400_600_oo_ber=np.array(scdom_400_600_oo_ber)
scdom_400_450_oo_ber=np.array(scdom_400_450_oo_ber)

# %%
scdom_clean_400_600 = scdom_400_600[~np.isnan(scdom_400_600)]
scdom_clean_400_450 = scdom_400_450[~np.isnan(scdom_400_450)]
scdom_clean_350_600 = scdom_350_600[~np.isnan(scdom_350_600)]
scdom_clean_350_450 = scdom_350_450[~np.isnan(scdom_350_450)]
scdom_clean_350_450_oo = scdom_350_450_oo[~np.isnan(scdom_350_450_oo)]
scdom_clean_350_600_oo_ber = scdom_350_600_oo_ber[~np.isnan(scdom_350_600_oo_ber)]
scdom_clean_350_450_oo_ber = scdom_350_450_oo_ber[~np.isnan(scdom_350_450_oo_ber)]
scdom_clean_400_600_oo_ber = scdom_400_600_oo_ber[~np.isnan(scdom_400_600_oo_ber)]
scdom_clean_400_450_oo_ber = scdom_400_450_oo_ber[~np.isnan(scdom_400_450_oo_ber)]

# %%
plt.rcParams.update({'font.size': 16}) 

fig, ax = plt.subplots(figsize=(12, 6)) 

#plt.plot(scdom_clean_400_600, marker='*', linestyle='None', color='blue')
#plt.plot(scdom_clean_400_450, marker='*', linestyle='None', color='green')
#plt.plot(scdom_clean_350_600, marker='.', linestyle='None', color='purple')
#plt.plot(scdom_clean_350_450, marker='.', linestyle='None', color='black')
ax.plot(scdom_clean_350_600_oo_ber, marker='.', linestyle='None', color='gold', label='350-600 nm')
#plt.plot(scdom_clean_350_450_oo_ber, marker='.', linestyle='None', color='blue')
ax.plot(scdom_clean_400_600_oo_ber, marker='.', linestyle='None', color='navy', label='400-600 nm')
#plt.plot(scdom_clean_400_450_oo_ber, marker='.', linestyle='None', color='red')
ax.set_ylim(0.016, 0.0201)
ax.set_xlim(0, 2600)
ax.set_ylabel(r'$S_{\text{CDOM}}$')
ax.set_xlabel('Pixel Number')
ax.legend()

plt.savefig('slope_comparisons_bermuda.png', format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
acdom_400_from_400_600=np.array(acdom_400_from_400_600)
acdom_400_from_400_450=np.array(acdom_400_from_400_450)
acdom_400_from_350_600=np.array(acdom_400_from_350_600)
acdom_400_from_350_450=np.array(acdom_400_from_350_450)
acdom_400_from_350_450_oo=np.array(acdom_400_from_350_450_oo)
acdom_400_from_350_600_oo_ber=np.array(acdom_400_from_350_600_oo_ber)
acdom_400_from_350_450_oo_ber=np.array(acdom_400_from_350_450_oo_ber)
acdom_400_from_400_600_oo_ber=np.array(acdom_400_from_400_600_oo_ber)
acdom_400_from_400_450_oo_ber=np.array(acdom_400_from_400_450_oo_ber)

# %%
acdom_clean_400_from_400_600 = acdom_400_from_400_600[~np.isnan(acdom_400_from_400_600)]
acdom_clean_400_from_400_450 = acdom_400_from_400_450[~np.isnan(acdom_400_from_400_450)]
acdom_clean_400_from_350_600 = acdom_400_from_350_600[~np.isnan(acdom_400_from_350_600)]
acdom_clean_400_from_350_450 = acdom_400_from_350_450[~np.isnan(acdom_400_from_350_450)]
acdom_clean_400_from_350_450_oo = acdom_400_from_350_450_oo[~np.isnan(acdom_400_from_350_450_oo)]
acdom_clean_400_from_350_600_oo_ber = acdom_400_from_350_600_oo_ber[~np.isnan(acdom_400_from_350_600_oo_ber)]
acdom_clean_400_from_350_450_oo_ber = acdom_400_from_350_450_oo_ber[~np.isnan(acdom_400_from_350_450_oo_ber)]
acdom_clean_400_from_400_600_oo_ber = acdom_400_from_400_600_oo_ber[~np.isnan(acdom_400_from_400_600_oo_ber)]
acdom_clean_400_from_400_450_oo_ber = acdom_400_from_400_450_oo_ber[~np.isnan(acdom_400_from_400_450_oo_ber)]

# %%
plt.rcParams.update({'font.size': 16}) 

fig, ax = plt.subplots(figsize=(12, 6)) 


#plt.plot(acdom_clean_400_from_400_600, marker='*', linestyle='None', color='blue')
#plt.plot(acdom_clean_400_from_400_450, marker='*', linestyle='None', color='green')
#plt.plot(acdom_clean_400_from_350_600, marker='.', linestyle='None', color='purple')
#plt.plot(acdom_clean_400_from_350_450, marker='.', linestyle='None', color='black')
ax.plot(acdom_clean_400_from_350_600_oo_ber, marker='.', linestyle='None', color='gold', label='350-600 nm')
#plt.plot(acdom_clean_400_from_350_450_oo_ber, marker='.', linestyle='None', color='blue')
ax.plot(acdom_clean_400_from_400_600_oo_ber, marker='.', linestyle='None', color='navy', label='400-600 nm')
#plt.plot(acdom_clean_400_from_400_450_oo_ber, marker='.', linestyle='None', color='red')

ax.set_ylim(0.02, 0.06)
ax.set_xlim(0, 2600)
ax.set_ylabel(r'$a_{\text{CDOM}} \, (400\, \text{nm})$')
ax.set_xlabel('Pixel Number')
ax.legend()

plt.savefig('acdom_comparisons_bermuda.png', format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.scatter(acdom_clean_400_from_350_600_oo_ber, scdom_clean_350_600_oo_ber)
plt.ylim(0.014, 0.0205)
plt.xlim(0, 0.06)
# Out:
# (0.0, 0.06)

# %%
plt.scatter(acdom_clean_400_from_400_600_oo_ber, scdom_clean_400_600_oo_ber)
plt.ylim(0.0195, 0.0205)
# Out:
# (0.0195, 0.0205)

# %%
chla_400_600 = pigments_400_600nm_oo_ber['chla']
chla_350_600 = pigments_350_600nm_oo_ber['chla']

# %%
chla_400_600=np.array(chla_400_600)
chla_350_600=np.array(chla_350_600)

# %%
chla_400_600_clean = chla_400_600[~np.isnan(chla_400_600)]
chla_350_600_clean = chla_350_600[~np.isnan(chla_350_600)]

# %%
plt.rcParams.update({'font.size': 16}) 

fig, ax = plt.subplots(figsize=(12, 6)) 

plt.plot(chla_350_600_clean, marker='.', linestyle='None', color='green', label='350-600 nm')
plt.plot(chla_400_600_clean, marker='.', linestyle='None', color='maroon', label='400-600 nm')

ax.set_ylim(0.001, 0.12)
ax.set_xlim(0, 2600)
ax.set_ylabel(r'$\text{Chla} \, (\text{mg m}^{-3})$')
ax.set_xlabel('Pixel Number')
ax.legend()

plt.savefig('chla_comparisons_bermuda.png', format='png', dpi=300, bbox_inches='tight')
plt.show()
